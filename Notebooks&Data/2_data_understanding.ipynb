# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib_inline
# %matplotlib inline

# %%
# set random seed
import random
random.seed(335)

# %%
# magic word
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
# for better viz
import pprint
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # data understanding
# ------------

# %%
# read csv file
df = pd.read_csv('/Users/esadmazi/Desktop/INNO/COURSES/DMining/LAB/CRISP-DMtemplate/Listings.csv')

# %%
# number of records and fields
df.shape # (records, fields)

# %%
# head
df.tail(n=5)
# Out:
#         user_id       id                                                uri  \
# 663941  3412025  5490437  شارع-وادي-طواء-حي-اليمامة-الرياض-امارة-منطقة-ا...
# 663942  1353258  5490438                                      الخبر-5490438
# 663943  1353258  5490440             شارع-11ب-حي-الكوثر-الخبر-الخبر-5490440
# 663944  1353258  5490442          شارع-الاحرار-حي-البحر-الخبر-الخبر-5490442
# 663945  1726598  5490444        حي-النرجس-الرياض-امارة-منطقة-الرياض-5490444
#
#                                                     title      price  \
# 663941  فيلا للبيع في شارع وادي طواء ، حي اليمامة ، ال...   650000.0
# 663942                                 أرض للبيع في الخبر  1120350.0
# 663943  أرض للبيع في شارع 11ب ، حي الكوثر ، الخبر ، الخبر   850000.0
# 663944  أرض للبيع في شارع الاحرار ، حي البحر ، الخبر ،...  4848900.0
# 663945  فيلا للبيع في حي النرجس ، الرياض ، امارة منطقة...  2500000.0
#
#                                                   content  \
# ...

# %%
# tail
df.tail(n=5)

# %%
# data types
df.dtypes
# Out:
# user_id                   int64
# id                        int64
# uri                      object
# title                    object
# price                   float64
# content                  object
# imgs                     object
# refresh                   int64
# category                  int64
# beds                    float64
# livings                 float64
# wc                      float64
# area                    float64
# type                    float64
# street_width            float64
# age                     float64
# last_update               int64
# street_direction        float64
# ketchen                 float64
# ac                      float64
# furnished               float64
# location.lat            float64
# location.lng            float64
# path                     object
# user.review             float64
# user.img                 object
# user.name                object
# user.phone                int64
# user.iam_verified       float64
# ...

# %% [markdown]
# ## explore data
# ----------

# %%
# Count NaN or empty values in each column
nan_counts = df.isna().sum()

# Filter columns with NaN values less than 1000
nan_counts_filtered = nan_counts[nan_counts >= 330000]

# Plotting
nan_counts_filtered.plot(kind='bar', color='skyblue')
plt.title('Number of NaN/Empty Values in Each Column')
plt.xlabel('Columns')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Define a function to categorize based on 'category' attribute
def categorize_rental_sell(category):
    if category in [1, 4, 5, 8, 11, 13, 14, 15, 16, 17, 18, 20, 23]:
        return 'Rental'
    elif category in [2, 3, 5, 7, 9, 10, 12, 19, 21, 22]:
        return 'Sell'

# Apply the function to create a new column 'category_type'
df['category_type'] = df['category'].apply(categorize_rental_sell)

# Display the first few rows of the DataFrame
# Split the DataFrame into rentals and sells
rentals_df = df[df['category_type'] == 'Rental']
sells_df = df[df['category_type'] == 'Sell']

# %%
# Count the number of rentals and sells
rentals_count = rentals_df.shape[0]
sells_count = sells_df.shape[0]

# Create a pie chart
labels = ['Rentals', 'Sells']
sizes = [rentals_count, sells_count]
colors = ['#ff9999', '#66b3ff']
explode = (0.1, 0)  # explode the 1st slice (Rentals)

plt.figure(figsize=(8, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, textprops={'fontsize': 16})
plt.title('Proportion of Rentals vs Sells', fontsize= 18)
# Adjust fontsize of other writings on the chart
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
sells_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 527405 entries, 0 to 663945
# Data columns (total 49 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               527405 non-null  int64
#  1   id                    527405 non-null  int64
#  2   uri                   527405 non-null  object
#  3   title                 527385 non-null  object
#  4   price                 527405 non-null  float64
#  5   content               516584 non-null  object
#  6   imgs                  488605 non-null  object
#  7   refresh               527405 non-null  int64
#  8   category              527405 non-null  int64
#  9   beds                  300668 non-null  float64
#  10  livings               301008 non-null  float64
#  11  wc                    299005 non-null  float64
#  12  area                  527333 non-null  float64
#  13  type                  155261 non-null  float64
# ...

# %%
sells_df.hist(['price'], range=[0, 10000000],figsize=(6,3))
sells_df.hist(['beds','wc'])
sells_df.hist(['age'],figsize=(6,3))

sells_df.hist(['width','length'], range=[0, 500])
# Out:
# array([[<Axes: title={'center': 'width'}>,
#         <Axes: title={'center': 'length'}>]], dtype=object)
